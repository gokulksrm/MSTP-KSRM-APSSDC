# %%
import pandas as pd

# %%
df =pd.read_csv('weatherByCities.csv')
df
# Out:
#          day       city  temperature  windspeed  event
# 0   1/1/2020     kadapa           32          6   Rain
# 1   1/2/2020     kadapa           36          7  Sunny
# 2   1/3/2020     kadapa           28         12   Snow
# 3   1/4/2020     kadapa           33          7  Sunny
# 4   1/1/2020  anantapur           32          6   Rain
# 5   1/2/2020  anantapur           36          7  Sunny
# 6   1/3/2020  anantapur           28         12   Snow
# 7   1/4/2020  anantapur           33          7  Sunny
# 8   1/1/2020   vempalli           32          6   Rain
# 9   1/2/2020   vempalli           36          7  Sunny
# 10  1/3/2020   vempalli           28         12   Snow
# 11  1/4/2020   vempalli           33          7  Sunny

# %%
df.head()
# Out:
#         day       city  temperature  windspeed  event
# 0  1/1/2020     kadapa           32          6   Rain
# 1  1/2/2020     kadapa           36          7  Sunny
# 2  1/3/2020     kadapa           28         12   Snow
# 3  1/4/2020     kadapa           33          7  Sunny
# 4  1/1/2020  anantapur           32          6   Rain

# %%
df.tail()
# Out:
#          day       city  temperature  windspeed  event
# 7   1/4/2020  anantapur           33          7  Sunny
# 8   1/1/2020   vempalli           32          6   Rain
# 9   1/2/2020   vempalli           36          7  Sunny
# 10  1/3/2020   vempalli           28         12   Snow
# 11  1/4/2020   vempalli           33          7  Sunny

# %%
df.index
# Out:
# RangeIndex(start=0, stop=12, step=1)

# %%
df.columns
# Out:
# Index(['day', 'city', 'temperature', 'windspeed', 'event'], dtype='object')

# %%
df=df.set_index('day')

# %%
df
# Out:
#                city  temperature  windspeed  event
# day
# 1/1/2020     kadapa           32          6   Rain
# 1/2/2020     kadapa           36          7  Sunny
# 1/3/2020     kadapa           28         12   Snow
# 1/4/2020     kadapa           33          7  Sunny
# 1/1/2020  anantapur           32          6   Rain
# 1/2/2020  anantapur           36          7  Sunny
# 1/3/2020  anantapur           28         12   Snow
# 1/4/2020  anantapur           33          7  Sunny
# 1/1/2020   vempalli           32          6   Rain
# 1/2/2020   vempalli           36          7  Sunny
# 1/3/2020   vempalli           28         12   Snow
# 1/4/2020   vempalli           33          7  Sunny

# %%
df.index
# Out:
# Index(['1/1/2020', '1/2/2020', '1/3/2020', '1/4/2020', '1/1/2020', '1/2/2020',
#        '1/3/2020', '1/4/2020', '1/1/2020', '1/2/2020', '1/3/2020', '1/4/2020'],
#       dtype='object', name='day')

# %%
df['temperature']
# Out:
# day
# 1/1/2020    32
# 1/2/2020    36
# 1/3/2020    28
# 1/4/2020    33
# 1/1/2020    32
# 1/2/2020    36
# 1/3/2020    28
# 1/4/2020    33
# 1/1/2020    32
# 1/2/2020    36
# 1/3/2020    28
# 1/4/2020    33
# Name: temperature, dtype: int64

# %%
df['temperature'].max()
# Out:
# 36

# %%
df['temperature'].count()
# Out:
# 12

# %%
df[['temperature','windspeed']]
# Out:
#           temperature  windspeed
# day
# 1/1/2020           32          6
# 1/2/2020           36          7
# 1/3/2020           28         12
# 1/4/2020           33          7
# 1/1/2020           32          6
# 1/2/2020           36          7
# 1/3/2020           28         12
# 1/4/2020           33          7
# 1/1/2020           32          6
# 1/2/2020           36          7
# 1/3/2020           28         12
# 1/4/2020           33          7

# %%
df[1:3]
# Out:
#             city  temperature  windspeed  event
# day
# 1/2/2020  kadapa           36          7  Sunny
# 1/3/2020  kadapa           28         12   Snow

# %%
df.iloc[[1,3,6]]
# Out:
#                city  temperature  windspeed  event
# day
# 1/2/2020     kadapa           36          7  Sunny
# 1/4/2020     kadapa           33          7  Sunny
# 1/3/2020  anantapur           28         12   Snow

# %%
import pandas as pd
  
# Define a dictionary containing students data
data = {'Name': ['Ankit', 'Amit',
                 'Aishwarya', 'Priyanka'],
        'Age': [21, 19, 20, 18],
        'Stream': ['Math', 'Commerce',
                   'Arts', 'Biology'],
        'Percentage': [88, 92, 95, 70]}
  
# Convert the dictionary into DataFrame
df = pd.DataFrame(data, columns=['Name', 'Age',
                                 'Stream', 
                                 'Percentage'])
  
print("Given Dataframe :\n", df)
  
print("\nIterating over rows using loc function :\n")
  
# iterate through each row and select
# 'Name' and 'Age' column respectively.
for i in range(len(df)):
    print(df.iloc[i, 0], df.iloc[i, 1])
# Out:
# Given Dataframe :
#          Name  Age    Stream  Percentage
# 0      Ankit   21      Math          88
# 1       Amit   19  Commerce          92
# 2  Aishwarya   20      Arts          95
# 3   Priyanka   18   Biology          70
#
# Iterating over rows using loc function :
#
# Ankit 21
# Amit 19
# Aishwarya 20
# Priyanka 18

# %%
df.loc[['1/2/2020','1/4/2020']]
# Out:
#                city  temperature  windspeed  event
# day
# 1/2/2020     kadapa           36          7  Sunny
# 1/2/2020  anantapur           36          7  Sunny
# 1/2/2020   vempalli           36          7  Sunny
# 1/4/2020     kadapa           33          7  Sunny
# 1/4/2020  anantapur           33          7  Sunny
# 1/4/2020   vempalli           33          7  Sunny

# %%
df['temperature'].max()
# Out:
# 36

# %%
df.temperature.min()
# Out:
# 28

# %%
df.temperature.mean()
# Out:
# 32.25

# %%
df.temperature.std()
# Out:
# 2.9886147596868655

# %%
df.temperature.describe()
# Out:
# count    12.000000
# mean     32.250000
# std       2.988615
# min      28.000000
# 25%      31.000000
# 50%      32.500000
# 75%      33.750000
# max      36.000000
# Name: temperature, dtype: float64

# %%
gdf=df.groupby('city')
gdf

# %%
gdf.groups
# Out:
# {'anantapur': ['1/1/2020', '1/2/2020', '1/3/2020', '1/4/2020'], 'kadapa': ['1/1/2020', '1/2/2020', '1/3/2020', '1/4/2020'], 'vempalli': ['1/1/2020', '1/2/2020', '1/3/2020', '1/4/2020']}

# %%
for c,d in gdf:
    print(c)
    print(d)
# Out:
# anantapur
#                city  temperature  windspeed  event
# day
# 1/1/2020  anantapur           32          6   Rain
# 1/2/2020  anantapur           36          7  Sunny
# 1/3/2020  anantapur           28         12   Snow
# 1/4/2020  anantapur           33          7  Sunny
# kadapa
#             city  temperature  windspeed  event
# day
# 1/1/2020  kadapa           32          6   Rain
# 1/2/2020  kadapa           36          7  Sunny
# 1/3/2020  kadapa           28         12   Snow
# 1/4/2020  kadapa           33          7  Sunny
# vempalli
#               city  temperature  windspeed  event
# day
# 1/1/2020  vempalli           32          6   Rain
# 1/2/2020  vempalli           36          7  Sunny
# 1/3/2020  vempalli           28         12   Snow
# 1/4/2020  vempalli           33          7  Sunny

# %%
gdf.max()
# Out:
#            temperature  windspeed  event
# city
# anantapur           36         12  Sunny
# kadapa              36         12  Sunny
# vempalli            36         12  Sunny

# %%
gdf=df.groupby(['temperature','windspeed'])

# %%
gdf.groups
# Out:
# {(28,
#   12): Index(['1/3/2020', '1/3/2020', '1/3/2020'], dtype='object', name='day'),
#  (32,
#   6): Index(['1/1/2020', '1/1/2020', '1/1/2020'], dtype='object', name='day'),
#  (33,
#   7): Index(['1/4/2020', '1/4/2020', '1/4/2020'], dtype='object', name='day'),
#  (36,
#   7): Index(['1/2/2020', '1/2/2020', '1/2/2020'], dtype='object', name='day')}

# %%
gdf=df.groupby('event')

# %%
gdf.get_group('Sunny')
# Out:
#                city  temperature  windspeed  event
# day
# 1/2/2020     kadapa           36          7  Sunny
# 1/4/2020     kadapa           33          7  Sunny
# 1/2/2020  anantapur           36          7  Sunny
# 1/4/2020  anantapur           33          7  Sunny
# 1/2/2020   vempalli           36          7  Sunny
# 1/4/2020   vempalli           33          7  Sunny

# %%
gdf.get_group('Rain')
# Out:
#                city  temperature  windspeed event
# day
# 1/1/2020     kadapa           32          6  Rain
# 1/1/2020  anantapur           32          6  Rain
# 1/1/2020   vempalli           32          6  Rain

# %%
df.where(df['city']=='kadapa')
# Out:
#             city  temperature  windspeed  event
# day
# 1/1/2020  kadapa         32.0        6.0   Rain
# 1/2/2020  kadapa         36.0        7.0  Sunny
# 1/3/2020  kadapa         28.0       12.0   Snow
# 1/4/2020  kadapa         33.0        7.0  Sunny
# 1/1/2020     NaN          NaN        NaN    NaN
# 1/2/2020     NaN          NaN        NaN    NaN
# 1/3/2020     NaN          NaN        NaN    NaN
# 1/4/2020     NaN          NaN        NaN    NaN
# 1/1/2020     NaN          NaN        NaN    NaN
# 1/2/2020     NaN          NaN        NaN    NaN
# 1/3/2020     NaN          NaN        NaN    NaN
# 1/4/2020     NaN          NaN        NaN    NaN

# %%
df.where(df['temperature']>=30)
# Out:
#                city  temperature  windspeed  event
# day
# 1/1/2020     kadapa         32.0        6.0   Rain
# 1/2/2020     kadapa         36.0        7.0  Sunny
# 1/3/2020        NaN          NaN        NaN    NaN
# 1/4/2020     kadapa         33.0        7.0  Sunny
# 1/1/2020  anantapur         32.0        6.0   Rain
# 1/2/2020  anantapur         36.0        7.0  Sunny
# 1/3/2020        NaN          NaN        NaN    NaN
# 1/4/2020  anantapur         33.0        7.0  Sunny
# 1/1/2020   vempalli         32.0        6.0   Rain
# 1/2/2020   vempalli         36.0        7.0  Sunny
# 1/3/2020        NaN          NaN        NaN    NaN
# 1/4/2020   vempalli         33.0        7.0  Sunny

# %%
df[df['temperature']>=30]
# Out:
#                city  temperature  windspeed  event
# day
# 1/1/2020     kadapa           32          6   Rain
# 1/2/2020     kadapa           36          7  Sunny
# 1/4/2020     kadapa           33          7  Sunny
# 1/1/2020  anantapur           32          6   Rain
# 1/2/2020  anantapur           36          7  Sunny
# 1/4/2020  anantapur           33          7  Sunny
# 1/1/2020   vempalli           32          6   Rain
# 1/2/2020   vempalli           36          7  Sunny
# 1/4/2020   vempalli           33          7  Sunny

# %% [markdown]
# # merging

# %%
stu_data=pd.DataFrame({'Name':['gokul','srikanth','kiran'],
                      'Rollno':['5c5','502','539'],
                      'Branch':['CSE','CSE','CSE']})
stu_data
# Out:
#        Name Rollno Branch
# 0     gokul    5c5    CSE
# 1  srikanth    502    CSE
# 2     kiran    539    CSE

# %%
valid_info=pd.DataFrame({'Name':['gokul','upendra','kiran'],
                        'loveStatus':['yes','yes','yes'],
                        'lovers':[2,2,3]})
valid_info
# Out:
#       Name loveStatus  lovers
# 0    gokul        yes       2
# 1  upendra        yes       2
# 2    kiran        yes       3

# %%
pd.merge?

# %%
pd.merge(stu_data,valid_info)
# Out:
#     Name Rollno Branch loveStatus  lovers
# 0  gokul    5c5    CSE        yes       2
# 1  kiran    539    CSE        yes       3

# %%
pd.merge(stu_data,valid_info,how='left')
# Out:
#        Name Rollno Branch loveStatus  lovers
# 0     gokul    5c5    CSE        yes     2.0
# 1  srikanth    502    CSE        NaN     NaN
# 2     kiran    539    CSE        yes     3.0

# %%
pd.merge(stu_data,valid_info,how='right')
# Out:
#       Name Rollno Branch loveStatus  lovers
# 0    gokul    5c5    CSE        yes       2
# 1    kiran    539    CSE        yes       3
# 2  upendra    NaN    NaN        yes       2

# %%
pd.merge(stu_data,valid_info,how='outer')
# Out:
#        Name Rollno Branch loveStatus  lovers
# 0     gokul    5c5    CSE        yes     2.0
# 1  srikanth    502    CSE        NaN     NaN
# 2     kiran    539    CSE        yes     3.0
# 3   upendra    NaN    NaN        yes     2.0

# %%
valid_info['Rollno']=['5c5','532','539']
valid_info
# Out:
#       Name loveStatus  lovers Rollno
# 0    gokul        yes       2    5c5
# 1  upendra        yes       2    532
# 2    kiran        yes       3    539

# %%
pd.merge(stu_data,valid_info)
# Out:
#     Name Rollno Branch loveStatus  lovers
# 0  gokul    5c5    CSE        yes       2
# 1  kiran    539    CSE        yes       3

# %%
pd.merge(stu_data,valid_info,on='Rollno')
# Out:
#   Name_x Rollno Branch Name_y loveStatus  lovers
# 0  gokul    5c5    CSE  gokul        yes       2
# 1  kiran    539    CSE  kiran        yes       3

# %%
valid_info
# Out:
#       Name loveStatus  lovers Rollno
# 0    gokul        yes       2    5c5
# 1  upendra        yes       2    532
# 2    kiran        yes       3    539

# %%
stu_data
# Out:
#        Name Rollno Branch
# 0     gokul    5c5    CSE
# 1  srikanth    502    CSE
# 2     kiran    539    CSE

# %%
df1=pd.merge(stu_data,valid_info,on='Rollno',how='outer')
df1
# Out:
#      Name_x Rollno Branch   Name_y loveStatus  lovers
# 0     gokul    5c5    CSE    gokul        yes     2.0
# 1  srikanth    502    CSE      NaN        NaN     NaN
# 2     kiran    539    CSE    kiran        yes     3.0
# 3       NaN    532    NaN  upendra        yes     2.0

# %%
df1=df1.dropna()
df1
# Out:
#   Name_x Rollno Branch Name_y loveStatus  lovers
# 0  gokul    5c5    CSE  gokul        yes     2.0
# 2  kiran    539    CSE  kiran        yes     3.0

# %%
df
# Out:
#           city  temperature  windspeed  event
# day
# 1/1/2020   NaN           32          6    NaN
# 1/2/2020   NaN           36          7    NaN
# 1/3/2020   NaN           28         12    NaN
# 1/4/2020   NaN           33          7    NaN
# 1/1/2020   NaN           32          6    NaN
# 1/2/2020   NaN           36          7    NaN
# 1/3/2020   NaN           28         12    NaN
# 1/4/2020   NaN           33          7    NaN
# 1/1/2020   NaN           32          6    NaN
# 1/2/2020   NaN           36          7    NaN
# 1/3/2020   NaN           28         12    NaN
# 1/4/2020   NaN           33          7    NaN

# %%
df1=pd.merge(stu_data,valid_info,on='Rollno',how='outer')

# %%
df1
# Out:
#      Name_x Rollno Branch   Name_y loveStatus  lovers
# 0     gokul    5c5    CSE    gokul        yes     2.0
# 1  srikanth    502    CSE      NaN        NaN     NaN
# 2     kiran    539    CSE    kiran        yes     3.0
# 3       NaN    532    NaN  upendra        yes     2.0

# %%
df1.isnull().sum()
# Out:
# city           12
# temperature     0
# windspeed       0
# event          12
# dtype: int64

# %%
df1.fillna(value='0',inplace=True)

# %%
df1
# Out:
#      Name_x Rollno Branch   Name_y loveStatus lovers
# 0     gokul    5c5    CSE    gokul        yes      2
# 1  srikanth    502    CSE        0          0      0
# 2     kiran    539    CSE    kiran        yes      3
# 3         0    532      0  upendra        yes      2
